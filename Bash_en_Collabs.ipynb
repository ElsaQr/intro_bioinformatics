# %% [markdown]
# <a href="https://colab.research.google.com/github/ElsaQr/intro_bioinformatics/blob/main/Bash_en_Collabs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ejecutar Bash en Google Colab 🚀
#
# ## 🛠️ ¿Cómo ejecutar bash en Google Colab?
#
# ### 1. Abre Google Colab
# - Ve a [Google Colab](https://colab.research.google.com).
#
# ### 2. Crea un nuevo notebook
# - Haz clic en **Archivo > Nuevo cuaderno**.
#
# ### 3. Añade una celda para bash
# - Escribe `!` al inicio de la celda para indicar que es un comando de **bash**.
#
# Ejemplo:

# %%
# !echo "Hola desde bash en Colab"
# Out:
# Hola desde bash en Colab

# %% [markdown]
# # Ejecuta scripts bash completos
# Si tienes un script .sh, puedes subirlo a tu Colab y ejecutarlo:

# %%
# !bash Separar datos de DB de TElements.ipynb
# Out:
# bash: Separar: No such file or directory
